# %%
n = int(input("Enter the number : "))

if(n > 0):
    print(f"Number is +ve")
elif(n < 0):
    print(f"Number is -ve")
else:
    print(f"NUmmber is Zero")
# Out:
# Enter the number :  -25
# Number is -ve

# %% [raw]
# What is programming?
# programming is the process of creatingn step-by-step instructions (code) that tell a coumpter how to perform tasks, solve problems, or automate processes.

# %% [raw]
# What are the types of Applications?
# desktop  Applications
# Web Applications
# Mobile Applications

# %% [raw]
# What is python?
# python is high level programming language:
# python supports:
# structured programming language
# object oriented programming language
# functional programming
# procedural programming
# python version:
# 3.14.4 : current version
# 3.13.13 : stable version

# %%
from math import factorial

# %%
factorial(5)
# Out:
# 120

# %%
factorial(6)
# Out:
# 720
